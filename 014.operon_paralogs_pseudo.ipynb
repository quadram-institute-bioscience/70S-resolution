# %% [markdown]
# # Effect of paralog choice on rRNA full operons
# - Pseudomonas (also can try on Staph)
#
# -> iqtree -s o.fas -wbtl -bb  --> o.fas.uboot will have ultrafast bootsrap trees w blens

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

from Bio import Seq, SeqIO, Align, AlignIO, Phylo, Alphabet, pairwise2 
from Bio.SeqRecord import SeqRecord
from Bio.Align import AlignInfo, Applications
from Bio.Phylo import draw, TreeConstruction  #TreeConstruction.DistanceCalculator, TreeConstruction.DistanceTreeConstructor 
# https://bioinformatics.stackexchange.com/questions/4337/biopython-phylogenetic-tree-replace-branch-tip-labels-by-sequence-logos

import numpy as np
import seaborn as sns
from sklearn import manifold, metrics, cluster, neighbors, decomposition, preprocessing
import skbio, parasail, dendropy
import sys, gzip, re, glob, pickle, collections, subprocess, os, errno, random, itertools

def print_redblack(textr, textb=""):
    print ('\x1b[0;1;31;1m'+ str(textr) + '\x1b[0;1;30;1m'+ str(textb) + '\x1b[0m')

# %% [markdown]
# ### defining main variables

# %%
##  "Mycobacterium" is not truely positive or negative
gram_positive = ["Clostridium", "Enterococcus", "Listeria", "Mycobacterium", "Staphylococcus", "Streptococcus"]
gram_negative = ["Campylobacter", "Escherichia", "Helicobacter", "Leptospira", 
                 "Neisseria", "Pseudomonas", "Salmonella"]
#outdir = "/usr/users/QIB_fr005/deolivl/Academic/Quadram/005.metagenomics_70S/notebooks/20190215.013_results/"
bacteria_genus = "Pseudomonas"  #  "Staphylococcus"
outdir = "./014_results/" + bacteria_genus
rrna_types = ["16S", "23S", "5S"];

# %% [markdown]
# ### read refseq genomes

# %%
## read species names translation tables and keep only genus+species 
file_name = glob.glob("/media/deolivl/QIB_deolivl/bigdata/" + bacteria_genus + "*/names.txt")[0]
file_lines = [line.strip() for line in open(file_name, 'r')]
thistbl = [line.split('\t') for line in file_lines[1:]] # concatenation of lists
fnames = glob.glob("/media/deolivl/QIB_deolivl/bigdata/" + bacteria_genus + "*/GCF_*.gbff.gz")
idx=[i for j in thistbl for i,fname in enumerate(fnames) if j[0] in fname]
table_filenames_species = [[fnames[idx[i]]] + j for i,j in enumerate(thistbl)]
table_filenames_species = [line + ["_".join(line[2].split()[:2]).split('.')[0]] for line in table_filenames_species]
table_filenames_species = [line + [line[2].split()[0]] for line in table_filenames_species]
print_redblack ("table_filenames_species[] has:"," filename,  GCF_id, full species_subsp name, species name (genus+sp), genus\n")

print (table_filenames_species[0], "\n", set([x[4] for x  in table_filenames_species]))

species_counter = collections.Counter([x[3] for x in table_filenames_species if x[3][-3:] !="_sp"])
print_redblack ("distinct species: ", species_counter)

def return_species_name_from_table (table_fs):
    return str(table_fs[3]) + "_" + str(re.search('GCF_(\d+)\.', table_fs[1]).group(1))

tbl_fl_sp = [x  for x in table_filenames_species if species_counter[ x[3] ] > 2]
print_redblack(set([x[3] for x  in tbl_fl_sp]))
random.shuffle(tbl_fl_sp)
# Out:
# table_filenames_species[] has: filename,  GCF_id, full species_subsp name, species name (genus+sp), genus
#
# ['/media/deolivl/QIB_deolivl/bigdata/Pseudomonas/GCF_000006765.1_ASM676v1_genomic.gbff.gz', 'GCF_000006765.1', 'Pseudomonas aeruginosa PAO1', 'Pseudomonas_aeruginosa', 'Pseudomonas']
#  {'Pseudomonas'}
# distinct species: Counter({'Pseudomonas_aeruginosa': 171, 'Pseudomonas_chlororaphis': 42, 'Pseudomonas_syringae': 29, 'Pseudomonas_putida': 28, 'Pseudomonas_fluorescens': 21, 'Pseudomonas_stutzeri': 17, 'Pseudomonas_protegens': 6, 'Pseudomonas_synxantha': 6, 'Pseudomonas_mendocina': 6, 'Pseudomonas_monteilii': 5, 'Pseudomonas_orientalis': 5, 'Pseudomonas_brassicacearum': 4, 'Pseudomonas_koreensis': 3, 'Pseudomonas_entomophila': 3, 'Pseudomonas_frederiksbergensis': 3, 'Pseudomonas_parafulva': 3, 'Pseudomonas_fragi': 2, 'Pseudomonas_taetrolens': 2, 'Pseudomonas_savastanoi': 2, 'Pseudomonas_fulva': 2, 'Pseudomonas_azotoformans': 2, 'Pseudomonas_pseudoalcaligenes': 2, 'Pseudomonas_mosselii': 2, 'Pseudomonas_plecoglossicida': 2, 'Pseudomonas_amygdali': 2, 'Pseudomonas_cerasi': 2, 'Pseudomonas_citronellolis': 2, 'Pseudomonas_cichorii': 1, 'Pseudomonas_resinovorans': 1, 'Pseudomonas_oryzihabitans': 1, 'Pseudomonas_alkylphenolica': 1, 'Pseudomonas_alcaliphila': 1, 'Pseudomonas_alcaligenes': 1, 'Pseudomonas_balearica': 1, 'Pseudomonas_libanensis': 1, 'Pseudomonas_silesiensis': 1, 'Pseudomonas_mandelii': 1, 'Pseudomonas_corrugata': 1, 'Pseudomonas_veronii': 1, 'Pseudomonas_yamanorum': 1, 'Pseudomonas_antarctica': 1, 'Pseudomonas_soli': 1, 'Pseudomonas_furukawaii': 1, 'Pseudomonas_knackmussii': 1, 'Pseudomonas_poae': 1, 'Pseudomonas_versuta': 1, 'Pseudomonas_trivialis': 1, 'Pseudomonas_avellanae': 1, 'Pseudomonas_viridiflava': 1, 'Pseudomonas_cremoricolorata': 1, 'Pseudomonas_lurida': 1, 'Pseudomonas_kribbensis': 1, 'Pseudomonas_mucidolens': 1, 'Pseudomonas_rhizosphaerae': 1, 'Pseudomonas_psychrotolerans': 1})
# {'Pseudomonas_frederiksbergensis', 'Pseudomonas_protegens', 'Pseudomonas_monteilii', 'Pseudomonas_koreensis', 'Pseudomonas_mendocina', 'Pseudomonas_syringae', 'Pseudomonas_stutzeri', 'Pseudomonas_parafulva', 'Pseudomonas_fluorescens', 'Pseudomonas_aeruginosa', 'Pseudomonas_chlororaphis', 'Pseudomonas_putida', 'Pseudomonas_brassicacearum', 'Pseudomonas_entomophila', 'Pseudomonas_orientalis', 'Pseudomonas_synxantha'}

# %% [markdown]
# ### main functions
# * find all operons, align sequences

# %%
def align_seqs (sequences=None, maxiters=12, infile=None, outfile=None, mafft = True):
    print ("started aligning...", flush=True, end=" ")
    if (sequences is None) and (infile is None):
        print ("ERROR: You must give me an alignment object or file")
        return [] ## OTOH if both are present then infile is overwritten with contents of sequences[]
    if infile is None:
        ifl = "/tmp/in.fas"
    else:
        ifl = infile
    if outfile is None:
        ofl = "/tmp/out.fas"
    else:
        ofl = outfile
    SeqIO.write(sequences, ifl, "fasta")
    if (mafft is False):
        proc_run = subprocess.check_output("muscle -in " + ifl + " -diags -maxiters " + str(maxiters) + " -out " + ofl,
                                       shell=True, universal_newlines=True)
    else: # "--parttree --6merpair" and 0.123 is to avoid very long alignments
        proc_run = subprocess.check_output("mafft --ep 0.3 --op 3.0 --auto " + ifl + " > " + ofl,
                                       shell=True, universal_newlines=True)
      
    aligned = AlignIO.read(ofl, "fasta")
    print ("Finished",flush=True)
    if infile is None:
        os.system("rm -f " + ifl)
    if outfile is None:
        os.system("rm -f " + ofl)
    return aligned

def return_contig_locations (featurelist): # featurelist has list of [ [location1, location2], rnaname, strand ]
    featurelist = sorted(featurelist, key = lambda x: int(x[0][0]))
    rnablocks = []
    rnabnames = []
    rnasignal = []
    tmp_loc = list(featurelist[0][0]) # start and end locations
    tmp_nam = [featurelist[0][1]]    # gene name
    tmp_sig = [featurelist[0][2]]
    for feature in featurelist[1:]:
        if (abs(tmp_loc[-1] - feature[0][0]) < 1000):
            tmp_loc.extend(list(feature[0]))
            tmp_nam.extend([feature[1]])
            tmp_sig.extend([feature[2]])
        else:
            rnablocks.append(tmp_loc)
            rnabnames.append(tmp_nam)
            rnasignal.append(tmp_sig)
            tmp_loc = list(feature[0])
            tmp_nam = [feature[1]]
            tmp_sig = [feature[2]]
    rnablocks.append(tmp_loc)
    rnabnames.append(tmp_nam)
    rnasignal.append(tmp_sig)
    return rnablocks, rnabnames, rnasignal
    
def get_rrna_from_genbank_to_list_and_dict (table_fs):
    gbank = SeqIO.parse(gzip.open(table_fs[0], "rt"), "genbank")
    list_of_features = []
    list_of_seqs = []
    genome = next(gbank) # no point in iterating over gbank, only this has whole information
    for feature in genome.features:
        if(feature.type == "rRNA"):
            for rna in rrna_types:
                if rna in feature.qualifiers['product'][0]:
                    this_product = rna
                    break
            this_location = [int(i) for i in re.findall('\d+',str(feature.location))]
            this_strand = feature.strand
            if 0 not in this_location:
                list_of_features.append([this_location[:2], this_product, this_strand])
    # now list_of_features is complete  for this genome record (gbank[0])
    if not list_of_features:
        print ("no info from ", table_fs[0])
        return None # some genomes have no relevant annotation
    location, gnames, strand = return_contig_locations (list_of_features)
    genome_len = len(genome.seq)
    for i, (l,g,s) in enumerate(zip(location, gnames, strand)):
        i_start = min(l); i_end = max(l)
        if sum(s) < 0: ## hopefully they all have same signal
            contig = genome.seq[i_start:i_end].reverse_complement()
            seqname = "s" + "".join(g[::-1])
        else:
            contig = genome.seq[i_start:i_end]
            seqname = "s" + "".join(g)
        numbercode = '_{:02d}'.format(i)
        seqname = return_species_name_from_table(table_fs) + numbercode
        if (len(contig) > 3000) and (len(contig) < 8500): # some contigs have only 5S; some genomes have only this 5S annotated
            list_of_seqs.append(SeqRecord(contig, id = seqname, description = seqname))
    return list_of_seqs

# %% [markdown]
# ### sample genomes and create unaligned list

# %%
good_fl_sp = []
rna_operon = []  # includes all paralogs
for file_counter, tfs in enumerate(tbl_fl_sp[:200]):
    if not (file_counter+1)%20:
        print (str(file_counter+1), end=" ", flush=True)
    rna_list = get_rrna_from_genbank_to_list_and_dict (tfs)
    # (some list will have no usable features or b/c too long/too short; some dict has no usable features
    if rna_list:
        good_fl_sp.append(tfs)
        rna_operon.extend(rna_list)

# save table, remembering that 'outdir' has the genus name already
fl=gzip.open(outdir+"_fl_sp.pickle.gz", "w"); pickle.dump([good_fl_sp],fl,2); fl.close()

print ("# first sequence of operon alignment:\n", rna_operon[0])
x = [len(i.seq) for i in rna_operon]
print ("# percentiles:", np.min(x), np.percentile(x, 5), np.mean(x), np.percentile(x, 95), np.max(x), len(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-35f3c6b5fa8b> in <module>
#       4     if not (file_counter+1)%20:
#       5         print (str(file_counter+1), end=" ", flush=True)
# ----> 6     rna_list = get_rrna_from_genbank_to_list_and_dict (tfs)
#       7     # (some list will have no usable features or b/c too long/too short; some dict has no usable features
#       8     if rna_list:
#
# <ipython-input-4-843c8a61bb50> in get_rrna_from_genbank_to_list_and_dict(table_fs)
#      57     list_of_features = []
#      58     list_of_seqs = []
# ---> 59     genome = next(gbank) # no point in iterating over gbank, only this has whole information
#      60     for feature in genome.features:
#      61         if(feature.type == "rRNA"):
#
# /usr/local/lib/python3.5/dist-packages/Bio/SeqIO/__init__.py in parse(handle, format, alphabet)
#     653             raise ValueError("Unknown format '%s'" % format)
#     654         # This imposes some overhead... wait until we drop Python 2.4 to fix it
# --> 655         for r in i:
#     656             yield r
#     657
#
# /usr/local/lib/python3.5/dist-packages/Bio/GenBank/Scanner.py in parse_records(self, handle, do_features)
#     487         # This is a generator function
#     488         while True:
# --> 489             record = self.parse(handle, do_features)
#     490             if record is None:
#     491                 break
#
# /usr/local/lib/python3.5/dist-packages/Bio/GenBank/Scanner.py in parse(self, handle, do_features)
#     471                                     feature_cleaner=FeatureValueCleaner())
#     472
# --> 473         if self.feed(handle, consumer, do_features):
#     474             return consumer.data
#     475         else:
#
# /usr/local/lib/python3.5/dist-packages/Bio/GenBank/Scanner.py in feed(self, handle, consumer, do_features)
#     443         # Features (common to both EMBL and GenBank):
#     444         if do_features:
# --> 445             self._feed_feature_table(consumer, self.parse_features(skip=False))
#     446         else:
#     447             self.parse_features(skip=True)  # ignore the data
#
# /usr/local/lib/python3.5/dist-packages/Bio/GenBank/Scanner.py in parse_features(self, skip)
#     211                     feature_lines.append(line[self.FEATURE_QUALIFIER_INDENT:].strip())
#     212                     line = self.handle.readline()
# --> 213                 features.append(self.parse_feature(feature_key, feature_lines))
#     214         self.line = line
#     215         return features
#
# /usr/local/lib/python3.5/dist-packages/Bio/GenBank/Scanner.py in parse_feature(self, feature_key, lines)
#     324                         value = '\n'.join(value_list)
#     325                         # DO NOT remove the quotes...
# --> 326                         qualifiers.append((key, value))
#     327                     else:
#     328                         # Unquoted
#
# KeyboardInterrupt:

# %%
# align each of the dictionary values (lists of unaligned seqs)
operon_aligned = align_seqs(sequences=rna_operon, outfile=outdir + ".fasta")
# Out:
# started aligning... Finished

# %%
def create_species_genus_labels (seqlist, have_paralogs = False): 
    species = ['_'.join(sequence.id.split('_')[:2]) for sequence in seqlist]
    genus = [sequence.id.split('_')[0] for sequence in seqlist]
    if have_paralogs:# assumes 'genus_species_code_number' names 
        sample = ['_'.join(sequence.id.split('_')[:3]) for sequence in seqlist]
        return species, genus, sample
    return species, genus

# %% [markdown]
# ### if resuming from previous analysis, run code below to read genome names table and alignments

# %%
# read table
fl=gzip.open(outdir+"_fl_sp.pickle.gz", "r"); good_fl_sp = pickle.load(fl); fl.close()
operon_aligned = AlignIO.read(outdir + ".fasta", "fasta")

# %%
outcheck = subprocess.check_output("muscle -maketree -in " + outdir + ".fasta -out " + outdir + "_upgma.treefile", shell=True,universal_newlines=True)
outcheck = subprocess.check_output("iqtree-omp -s " + outdir + ".fasta -nt 8 -m HKY+G",shell=True,universal_newlines=True)
print (outcheck)
# Out:
# IQ-TREE multicore version 1.3.11.1 for Linux 64-bit built Feb  1 2016
# Copyright (c) 2011-2015 Nguyen Lam Tung, Olga Chernomor, Arndt von Haeseler and Bui Quang Minh.
#
# Host:    n114312.nbi.ac.uk (AVX2, FMA3, 15 GB RAM)
# Command: iqtree-omp -s ./014_results/Pseudomonas.fasta -nt 8 -m HKY+G
# Seed:    410298 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Mon Feb 25 09:45:50 2019
# Kernel:  AVX - 8 threads (8 CPU cores detected)
#
# Reading alignment file ./014_results/Pseudomonas.fasta ... Fasta format detected
# Alignment most likely contains DNA/RNA sequences
# Alignment has 923 sequences with 7793 columns and 1739 patterns (1117 informative sites)
#                                              Gap/Ambiguity  Composition  p-value
#    1  Pseudomonas_aeruginosa_000510305_00           33.81%    passed     99.30%
#    2  Pseudomonas_aeruginosa_000510305_01           33.81%    passed     98.49%
#    3  Pseudomonas_aeruginosa_000510305_02           33.83%    passed     98.59%
#    4  Pseudomonas_aeruginosa_000510305_03           33.83%    passed     98.40%
#    5  Pseudomonas_aeruginosa_003950015_00           33.84%    passed     98.06%
#    6  Pseudomonas_aeruginosa_003950015_01           33.83%    passed     98.43%
#    7  Pseudomonas_aeruginosa_003950015_02           33.84%    passed     98.57%
#    8  Pseudomonas_aeruginosa_003950015_03           33.83%    passed     97.94%
#    9  Pseudomonas_aeruginosa_001721765_00           33.83%    passed     98.00%
#   10  Pseudomonas_aeruginosa_001721765_01           33.81%    passed     97.59%
#   11  Pseudomonas_aeruginosa_001721765_02           33.81%    passed     98.30%
#   12  Pseudomonas_aeruginosa_001721765_03           33.84%    passed     97.82%
#   13  Pseudomonas_brassicacearum_001449085_00       29.90%    passed     96.58%
#   14  Pseudomonas_brassicacearum_001449085_01       32.98%    passed     99.84%
#   15  Pseudomonas_brassicacearum_001449085_02       32.76%    passed     99.59%
#   16  Pseudomonas_brassicacearum_001449085_03       32.98%    passed     99.84%
#   17  Pseudomonas_brassicacearum_001449085_04       32.98%    passed     99.82%
#   18  Pseudomonas_aeruginosa_002812885_00           33.83%    passed     97.93%
#   19  Pseudomonas_aeruginosa_002812885_01           33.83%    passed     97.93%
#  483  Pseudomonas_aeruginosa_900149285_00           33.83%    passed     97.67%
#  484  Pseudomonas_aeruginosa_900149285_01           33.84%    passed     96.95%
#  485  Pseudomonas_aeruginosa_900149285_02           33.83%    passed     97.67%
#  486  Pseudomonas_aeruginosa_900149285_03           33.83%    passed     97.67%
#  487  Pseudomonas_aeruginosa_900618245_00           33.81%    passed     99.15%
#  488  Pseudomonas_aeruginosa_900618245_01           33.81%    passed     99.15%
#  489  Pseudomonas_aeruginosa_900618245_03           59.48%    passed     89.14%
#  490  Pseudomonas_aeruginosa_900618245_04           33.81%    passed     99.15%
#  491  Pseudomonas_aeruginosa_000829275_00           33.84%    passed     99.04%
#  492  Pseudomonas_aeruginosa_000829275_01           33.84%    passed     99.04%
#  493  Pseudomonas_aeruginosa_000829275_02           33.84%    passed     98.51%
#  494  Pseudomonas_aeruginosa_000829275_03           33.84%    passed     99.04%
#  495  Pseudomonas_syringae_002966555_00             32.73%    passed     97.71%
#  496  Pseudomonas_syringae_002966555_01             32.73%    passed     97.29%
#  497  Pseudomonas_syringae_002966555_02             32.72%    passed     97.50%
#  498  Pseudomonas_syringae_002966555_03             32.73%    passed     97.71%
#  499  Pseudomonas_syringae_002966555_04             29.87%    passed     99.01%
#  500  Pseudomonas_aeruginosa_003952325_00           33.77%    passed     98.64%
#  501  Pseudomonas_aeruginosa_003952325_01           33.74%    passed     98.20%
#  502  Pseudomonas_aeruginosa_003952325_02           33.80%    passed     97.90%
#  503  Pseudomonas_aeruginosa_003952325_03           33.83%    passed     98.41%
#  504  Pseudomonas_putida_003228315_00               33.32%    passed     99.14%
#  505  Pseudomonas_putida_003228315_01               33.32%    passed     98.47%
#  506  Pseudomonas_putida_003228315_02               33.32%    passed     98.47%
#  507  Pseudomonas_putida_003228315_03               33.32%    passed     99.14%
#  508  Pseudomonas_putida_003228315_04               30.48%    passed     96.66%
#  509  Pseudomonas_putida_003228315_05               33.32%    passed     98.47%
#  510  Pseudomonas_aeruginosa_900069025_02           33.81%    passed     98.49%
#  511  Pseudomonas_aeruginosa_900069025_03           33.81%    passed     98.49%
#  512  Pseudomonas_aeruginosa_900069025_04           33.81%    passed     98.49%
#  513  Pseudomonas_putida_000410575_00               33.81%    passed     97.41%
#  514  Pseudomonas_putida_000410575_01               36.35%    passed     99.87%
#  515  Pseudomonas_putida_000410575_02               33.40%    passed     99.32%
#  516  Pseudomonas_putida_000410575_03               33.41%    passed     99.54%
#  517  Pseudomonas_putida_000410575_04               59.55%    passed     91.11%
#  518  Pseudomonas_putida_000410575_05               32.53%    passed     96.57%
#  519  Pseudomonas_stutzeri_000661915_00             32.99%    passed     99.76%
#  520  Pseudomonas_stutzeri_000661915_01             32.99%    passed     99.76%
#  521  Pseudomonas_stutzeri_000661915_02             32.99%    passed     99.76%
#  522  Pseudomonas_stutzeri_000661915_03             32.99%    passed     99.76%
#  523  Pseudomonas_aeruginosa_000271365_00           33.83%    passed     98.77%
#  524  Pseudomonas_aeruginosa_000271365_01           33.83%    passed     98.40%
#  525  Pseudomonas_aeruginosa_000271365_02           33.83%    passed     98.40%
#  526  Pseudomonas_aeruginosa_000271365_03           33.83%    passed     98.40%
#  527  Pseudomonas_aeruginosa_002215345_00           33.83%    passed     98.25%
#  528  Pseudomonas_aeruginosa_002215345_01           33.83%    passed     98.15%
#  529  Pseudomonas_aeruginosa_002215345_02           33.83%    passed     97.67%
#  530  Pseudomonas_aeruginosa_002215345_03           33.83%    passed     98.25%
#  531  Pseudomonas_aeruginosa_002968515_00           33.83%    passed     98.25%
#  532  Pseudomonas_aeruginosa_002968515_01           33.83%    passed     97.67%
#  533  Pseudomonas_aeruginosa_002968515_02           33.83%    passed     97.80%
#  534  Pseudomonas_aeruginosa_002968515_03           33.83%    passed     98.25%
#  535  Pseudomonas_aeruginosa_001516225_00           33.84%    passed     97.82%
#  536  Pseudomonas_aeruginosa_001516225_01           33.81%    passed     98.22%
#  537  Pseudomonas_aeruginosa_001516225_02           33.83%    passed     98.75%
#  538  Pseudomonas_aeruginosa_001516225_03           33.83%    passed     98.23%
#  539  Pseudomonas_aeruginosa_003028335_00           33.84%    passed     99.04%
#  540  Pseudomonas_aeruginosa_003028335_01           33.84%    passed     99.04%
#  541  Pseudomonas_aeruginosa_003028335_02           33.84%    passed     98.81%
#  542  Pseudomonas_aeruginosa_003028335_03           33.85%    passed     99.11%
#  543  Pseudomonas_aeruginosa_000508765_00           33.83%    passed     98.40%
#  544  Pseudomonas_aeruginosa_000508765_01           33.80%    passed     98.07%
#  545  Pseudomonas_aeruginosa_000508765_02           34.38%    passed     95.92%
#  546  Pseudomonas_aeruginosa_000508765_03           33.84%    passed     98.88%
#  547  Pseudomonas_putida_900636645_01               36.25%    passed     99.23%
#  548  Pseudomonas_putida_900636645_02               33.36%    passed     99.01%
#  549  Pseudomonas_putida_900636645_03               36.10%    passed     98.90%
#  550  Pseudomonas_putida_900636645_04               33.36%    passed     98.89%
#  551  Pseudomonas_putida_900636645_05               32.53%    passed     96.57%
#  552  Pseudomonas_orientalis_003852045_00           30.05%    passed     78.74%
#  553  Pseudomonas_orientalis_003852045_01           32.79%    passed     84.21%
#  554  Pseudomonas_orientalis_003852045_02           33.08%    passed     95.94%
#  555  Pseudomonas_orientalis_003852045_03           32.94%    passed     92.26%
#  556  Pseudomonas_orientalis_003852045_04           32.95%    passed     92.29%
#  557  Pseudomonas_orientalis_003852045_05           32.71%    passed     88.62%
#  558  Pseudomonas_aeruginosa_001548335_00           33.83%    passed     96.98%
#  559  Pseudomonas_aeruginosa_001548335_01           33.83%    passed     97.61%
#  560  Pseudomonas_aeruginosa_001548335_02           33.83%    passed     98.40%
#  561  Pseudomonas_aeruginosa_001548335_03           33.83%    passed     98.40%
#  562  Pseudomonas_aeruginosa_002237405_00           33.84%    passed     98.29%
#  563  Pseudomonas_aeruginosa_002237405_01           33.84%    passed     97.64%
#  564  Pseudomonas_aeruginosa_002237405_02           33.84%    passed     97.53%
#  565  Pseudomonas_aeruginosa_002237405_03           33.85%    passed     97.69%
#  566  Pseudomonas_stutzeri_000267545_00             33.21%    passed     99.67%
#  567  Pseudomonas_stutzeri_000267545_01             33.21%    passed     99.49%
#  568  Pseudomonas_stutzeri_000267545_02             33.20%    passed     99.47%
#  569  Pseudomonas_stutzeri_000267545_03             33.21%    passed     99.49%
#  570  Pseudomonas_aeruginosa_001721805_00           33.83%    passed     98.00%
#  571  Pseudomonas_aeruginosa_001721805_01           33.81%    passed     97.59%
#  572  Pseudomonas_aeruginosa_001721805_02           33.81%    passed     98.30%
#  573  Pseudomonas_aeruginosa_001721805_03           33.84%    passed     97.82%
#  574  Pseudomonas_aeruginosa_003571805_00           33.84%    passed     98.29%
#  575  Pseudomonas_aeruginosa_003571805_01           33.83%    passed     97.67%
#  576  Pseudomonas_aeruginosa_003571805_02           33.85%    passed     98.50%
#  577  Pseudomonas_aeruginosa_003571805_03           33.84%    passed     98.38%
#  578  Pseudomonas_syringae_002905815_00             32.77%    passed     98.80%
#  579  Pseudomonas_syringae_002905815_01             32.77%    passed     98.76%
#  580  Pseudomonas_syringae_002905815_02             32.57%    passed     99.99%
#  581  Pseudomonas_syringae_002905815_03             32.77%    passed     98.97%
#  582  Pseudomonas_syringae_002905815_04             32.77%    passed     99.03%
#  583  Pseudomonas_aeruginosa_003991465_00           33.79%    passed     97.99%
#  584  Pseudomonas_aeruginosa_003991465_01           33.80%    passed     97.80%
#  585  Pseudomonas_aeruginosa_003991465_02           33.80%    passed     97.38%
#  586  Pseudomonas_aeruginosa_003991465_03           33.80%    passed     98.11%
#  587  Pseudomonas_aeruginosa_000981825_00           33.83%    passed     97.35%
#  588  Pseudomonas_aeruginosa_000981825_01           33.83%    passed     97.35%
#  589  Pseudomonas_aeruginosa_000981825_02           33.83%    passed     97.35%
#  590  Pseudomonas_aeruginosa_000981825_03           33.83%    passed     97.35%
# ...
#  794  Pseudomonas_syringae_002763655_00             30.04%    passed     96.79%
#  795  Pseudomonas_syringae_002763655_01             32.80%    passed     97.00%
#  796  Pseudomonas_syringae_002763655_02             32.97%    passed     99.12%
#  797  Pseudomonas_syringae_002763655_03             32.85%    passed     97.76%
#  798  Pseudomonas_syringae_002763655_04             32.90%    passed     98.46%
#  799  Pseudomonas_brassicacearum_001746815_00       32.75%    passed     99.81%
#  800  Pseudomonas_brassicacearum_001746815_01       30.10%    passed     99.27%
#  801  Pseudomonas_brassicacearum_001746815_02       32.44%    passed     99.99%
#  802  Pseudomonas_brassicacearum_001746815_03       32.75%    passed     99.94%
#  803  Pseudomonas_brassicacearum_001746815_04       32.75%    passed     99.89%
#  804  Pseudomonas_chlororaphis_003851165_00         30.82%    passed     94.73%
#  805  Pseudomonas_chlororaphis_003851165_01         33.72%    passed     96.65%
#  806  Pseudomonas_chlororaphis_003851165_02         33.72%    passed     97.33%
#  807  Pseudomonas_chlororaphis_003851165_03         33.72%    passed     96.65%
#  808  Pseudomonas_chlororaphis_003851165_04         33.72%    passed     97.33%
#  809  Pseudomonas_putida_000226035_00               56.76%    passed     87.08%
#  810  Pseudomonas_putida_000226035_01               33.97%    passed     99.94%
#  811  Pseudomonas_putida_000226035_02               10.79%    passed     97.89%
#  812  Pseudomonas_putida_000226035_03               36.25%    passed     99.03%
#  855  Pseudomonas_chlororaphis_003851305_02         33.57%    passed     97.04%
#  856  Pseudomonas_chlororaphis_003851305_03         33.57%    passed     97.04%
#  857  Pseudomonas_chlororaphis_003851305_04         33.57%    passed     96.49%
#  858  Pseudomonas_chlororaphis_001023535_00         33.36%    passed     98.48%
#  859  Pseudomonas_chlororaphis_001023535_01         30.49%    passed     91.74%
#  860  Pseudomonas_chlororaphis_001023535_02         33.57%    passed     99.14%
#  861  Pseudomonas_chlororaphis_001023535_04         33.41%    passed     99.21%
#  862  Pseudomonas_chlororaphis_001023535_05         32.97%    passed     94.68%
#  863  Pseudomonas_aeruginosa_000473745_01           33.84%    passed     99.04%
#  864  Pseudomonas_aeruginosa_000473745_03           33.84%    passed     99.04%
#  865  Pseudomonas_syringae_001913235_00             32.79%    passed     97.23%
#  866  Pseudomonas_syringae_001913235_01             32.79%    passed     97.23%
#  867  Pseudomonas_syringae_001913235_02             32.79%    passed     97.63%
#  868  Pseudomonas_syringae_001913235_03             32.79%    passed     97.23%
#  869  Pseudomonas_syringae_001913235_04             29.92%    passed     98.24%
#  870  Pseudomonas_aeruginosa_001515915_00           33.84%    passed     98.29%
#  871  Pseudomonas_aeruginosa_001515915_01           33.83%    passed     98.15%
#  872  Pseudomonas_aeruginosa_001515915_02           33.83%    passed     98.81%
#  873  Pseudomonas_aeruginosa_001515915_03           33.81%    passed     98.27%
#  874  Pseudomonas_protegens_002208745_00            33.23%    passed     80.91%
#  875  Pseudomonas_protegens_002208745_01            30.28%    passed     61.24%
#  876  Pseudomonas_protegens_002208745_02            33.22%    passed     80.01%
#  877  Pseudomonas_protegens_002208745_03            33.25%    passed     81.94%
#  878  Pseudomonas_protegens_002208745_04            33.23%    passed     79.25%
#  879  Pseudomonas_aeruginosa_000829885_00           33.81%    passed     96.93%
#  880  Pseudomonas_aeruginosa_000829885_01           33.81%    passed     96.93%
#  881  Pseudomonas_aeruginosa_000829885_02           33.83%    passed     98.26%
#  882  Pseudomonas_aeruginosa_000829885_03           33.83%    passed     97.35%
#  883  Pseudomonas_aeruginosa_003193645_00           33.85%    passed     97.50%
#  884  Pseudomonas_aeruginosa_003193645_01           33.85%    passed     97.86%
#  885  Pseudomonas_aeruginosa_003193645_02           33.85%    passed     97.86%
#  886  Pseudomonas_aeruginosa_003193645_03           33.84%    passed     97.53%
#  887  Pseudomonas_aeruginosa_002192495_00           33.83%    passed     97.61%
#  888  Pseudomonas_aeruginosa_002192495_01           33.83%    passed     98.15%
#  889  Pseudomonas_aeruginosa_002192495_02           33.83%    passed     97.61%
#  890  Pseudomonas_aeruginosa_002192495_03           33.85%    passed     98.33%
#  891  Pseudomonas_aeruginosa_000017205_00           33.85%    passed     98.19%
#  892  Pseudomonas_aeruginosa_000017205_01           33.85%    passed     98.19%
#  893  Pseudomonas_aeruginosa_000017205_02           33.85%    passed     97.75%
#  894  Pseudomonas_aeruginosa_000017205_03           33.85%    passed     97.88%
#  895  Pseudomonas_aeruginosa_900637045_00           33.83%    passed     98.77%
#  896  Pseudomonas_aeruginosa_900637045_01           33.83%    passed     98.55%
#  897  Pseudomonas_aeruginosa_900637045_02           33.83%    passed     98.77%
#  898  Pseudomonas_aeruginosa_900637045_03           33.83%    passed     98.77%
#  899  Pseudomonas_aeruginosa_000414035_00           33.83%    passed     97.94%
#  900  Pseudomonas_aeruginosa_000414035_01           33.81%    passed     98.03%
#  901  Pseudomonas_aeruginosa_000414035_02           33.81%    passed     98.03%
#  902  Pseudomonas_aeruginosa_000414035_03           34.22%    passed     98.05%
#  903  Pseudomonas_stutzeri_003952645_00             30.04%    passed     83.85%
#  904  Pseudomonas_stutzeri_003952645_01             32.91%    passed     92.63%
#  905  Pseudomonas_stutzeri_003952645_02             32.73%    passed     85.62%
#  906  Pseudomonas_stutzeri_003952645_03             32.91%    passed     92.63%
#  907  Pseudomonas_stutzeri_003952645_04             32.75%    passed     83.90%
#  908  Pseudomonas_stutzeri_003952645_05             35.45%    passed     80.78%
#  909  Pseudomonas_stutzeri_003952645_06             32.91%    passed     93.36%
#  910  Pseudomonas_aeruginosa_003716765_00           33.76%    passed     84.72%
#  911  Pseudomonas_aeruginosa_003716765_01           33.86%    passed     98.68%
#  912  Pseudomonas_aeruginosa_003716765_02           33.81%    passed     97.33%
#  913  Pseudomonas_aeruginosa_003716765_03           33.79%    passed     97.44%
#  914  Pseudomonas_frederiksbergensis_002355315_00   33.12%    passed     99.14%
#  915  Pseudomonas_frederiksbergensis_002355315_01   32.17%    passed     95.44%
#  916  Pseudomonas_frederiksbergensis_002355315_02   32.91%    passed     99.22%
#  917  Pseudomonas_frederiksbergensis_002355315_03   32.18%    passed     95.50%
#  918  Pseudomonas_frederiksbergensis_002355315_04   32.17%    passed     95.44%
#  919  Pseudomonas_frederiksbergensis_002355315_05   32.77%    passed     91.80%
#  920  Pseudomonas_aeruginosa_000226155_00           33.85%    passed     98.47%
#  921  Pseudomonas_aeruginosa_000226155_01           33.85%    passed     98.47%
#  922  Pseudomonas_aeruginosa_000226155_02           33.85%    passed     98.47%
#  923  Pseudomonas_aeruginosa_000226155_03           33.85%    passed     98.47%
# WARNING: 7 sequences contain more than 50% gaps/ambiguity
# ****  TOTAL                                         33.59%  0 sequences failed composition chi2 test (p-value<5%; df=3)
# NOTE: 257 identical sequences will be ignored during tree search
#
# Create initial parsimony tree by phylogenetic likelihood library (PLL)... 0.319 seconds
#
# NOTE: 144 MB RAM is required!
# Estimate model parameters (epsilon = 0.100)
# 1. Initial log-likelihood: -59441.073
# 2. Current log-likelihood: -54268.379
# 3. Current log-likelihood: -53813.480
# 4. Current log-likelihood: -53811.548
# Optimal log-likelihood: -53811.487
# Rate parameters:  A-C: 1.000  A-G: 2.881  A-T: 1.000  C-G: 1.000  C-T: 2.881  G-T: 1.000
# Base frequencies:   A: 0.261  C: 0.219  G: 0.302  T: 0.218
# Gamma shape alpha: 0.161
# Parameters optimization took 4 rounds (2.482 sec)
#
# --------------------------------------------------------------------
# |             INITIALIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Computing ML distances based on estimated model parameters... 8.076 sec
# Computing BIONJ tree...
# 0.446 seconds
# Log-likelihood of BIONJ tree: -55064.511
# Generating 98 parsimony trees... 34.822 seconds 100 distinct starting trees
# Computing log-likelihood of 100 initial trees ... 39.571 seconds
# Optimizing top 20 initial trees with NNI...
# Iteration 1 / LogL: -53643.863 / Time: 0h:1m:21s
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 1: -53643.794
# Iteration 2 / LogL: -53621.187 / Time: 0h:1m:23s
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 2: -53620.973
# Iteration 3 / LogL: -53631.446 / Time: 0h:1m:27s
# Iteration 4 / LogL: -53669.279 / Time: 0h:1m:33s
# Iteration 5 / LogL: -53669.476 / Time: 0h:1m:35s
# Iteration 6 / LogL: -53713.280 / Time: 0h:1m:37s
# Iteration 7 / LogL: -53688.984 / Time: 0h:1m:39s
# Iteration 8 / LogL: -53610.775 / Time: 0h:1m:42s
# Estimate model parameters (epsilon = 0.100)
# BETTER TREE FOUND at iteration 8: -53610.715
# Iteration 9 / LogL: -53683.731 / Time: 0h:1m:46s
# Iteration 10 / LogL: -53672.747 / Time: 0h:1m:47s
# Iteration 11 / LogL: -53681.166 / Time: 0h:1m:49s
# Iteration 12 / LogL: -53661.419 / Time: 0h:1m:50s
# Iteration 13 / LogL: -53658.682 / Time: 0h:1m:52s
# Iteration 14 / LogL: -53686.689 / Time: 0h:1m:54s
# Iteration 15 / LogL: -53701.104 / Time: 0h:1m:55s
# Iteration 16 / LogL: -53709.990 / Time: 0h:1m:57s
# Iteration 17 / LogL: -53687.064 / Time: 0h:1m:59s
# Iteration 18 / LogL: -53696.392 / Time: 0h:2m:0s
# Iteration 19 / LogL: -53733.763 / Time: 0h:2m:2s
# Iteration 20 / LogL: -53671.125 / Time: 0h:2m:4s
# Average CPU time for 1 NNI search: 16.748
# Finish initializing candidate tree set. Number of distinct locally optimal trees: 20
# Current best tree score: -53610.715 / CPU time: 662.672
# --------------------------------------------------------------------
# |               OPTIMIZING CANDIDATE TREE SET                      |
# --------------------------------------------------------------------
# Iteration 30 / LogL: -53665.578 / Time: 0h:2m:30s (0h:6m:8s left)
# Iteration 40 / LogL: -53804.485 / Time: 0h:2m:55s (0h:4m:34s left)
# Iteration 50 / LogL: -53852.261 / Time: 0h:3m:21s (0h:3m:29s left)
# Iteration 60 / LogL: -53639.157 / Time: 0h:3m:52s (0h:2m:41s left)
# Iteration 70 / LogL: -53805.293 / Time: 0h:4m:16s (0h:1m:55s left)
# Iteration 80 / LogL: -53665.327 / Time: 0h:4m:58s (0h:1m:19s left)
# Estimate model parameters (epsilon = 0.010)
# BETTER TREE FOUND at iteration 86: -53593.369
# Iteration 90 / LogL: -53953.464 / Time: 0h:5m:27s (0h:5m:53s left)
# Iteration 100 / LogL: -53644.263 / Time: 0h:6m:13s (0h:5m:23s left)
# Iteration 110 / LogL: -53761.446 / Time: 0h:6m:45s (0h:4m:42s left)
# Iteration 120 / LogL: -53789.794 / Time: 0h:7m:15s (0h:4m:1s left)
# Iteration 130 / LogL: -53714.681 / Time: 0h:7m:57s (0h:3m:27s left)
# Iteration 140 / LogL: -53640.258 / Time: 0h:8m:36s (0h:2m:50s left)
# Iteration 150 / LogL: -53630.313 / Time: 0h:9m:2s (0h:2m:10s left)
# Iteration 160 / LogL: -53982.217 / Time: 0h:9m:26s (0h:1m:32s left)
# Iteration 170 / LogL: -53782.119 / Time: 0h:9m:50s (0h:0m:55s left)
# Iteration 180 / LogL: -53734.150 / Time: 0h:10m:14s (0h:0m:20s left)
# TREE SEARCH COMPLETED AFTER 186 ITERATIONS / Time: 0h:10m:29s
#
# --------------------------------------------------------------------
# |                    FINALIZING TREE SEARCH                        |
# --------------------------------------------------------------------
# Performs final model parameters optimization
# Estimate model parameters (epsilon = 0.010)
# 1. Initial log-likelihood: -53593.356
# 2. Current log-likelihood: -53593.333
# Optimal log-likelihood: -53593.333
# Rate parameters:  A-C: 1.000  A-G: 2.892  A-T: 1.000  C-G: 1.000  C-T: 2.892  G-T: 1.000
# Base frequencies:   A: 0.261  C: 0.219  G: 0.302  T: 0.218
# Gamma shape alpha: 0.161
# Parameters optimization took 2 rounds (0.802 sec)
#
# BEST SCORE FOUND : -53593.333
# Total tree length: 4.836
#
# Total number of iterations: 186
# CPU time used for tree search: 4480.776 sec (1h:14m:40s)
# Wall-clock time used for tree search: 623.517 sec (0h:10m:23s)
# Total CPU time used: 4524.552 sec (1h:15m:24s)
# Total wall-clock time used: 630.066 sec (0h:10m:30s)
#
# Analysis results written to:
#   IQ-TREE report:                ./014_results/Pseudomonas.fasta.iqtree
#   Maximum-likelihood tree:       ./014_results/Pseudomonas.fasta.treefile
#   Likelihood distances:          ./014_results/Pseudomonas.fasta.mldist
#   Screen log file:               ./014_results/Pseudomonas.fasta.log
#
# Date and Time: Mon Feb 25 09:56:20 2019

# %%
def patristic_distances_from_treefile (filename, have_paralogs = False, shuffle = False):
    tree = dendropy.Tree.get(path=filename, schema="newick", preserve_underscores=True)
    if shuffle:
        tree = dendropy.simulate.treesim.pure_kingman_tree(taxon_namespace=tree.taxon_namespace, pop_size = 1000)
    species = ['_'.join(t.label.split('_')[:2]) for t in tree.taxon_namespace] ## follow order of taxon_namespace
    genus = [t.label.split('_')[0] for t in tree.taxon_namespace]
    ntaxa = len(tree.taxon_namespace)
    distmat = np.zeros((ntaxa,ntaxa)) # diagonals are zero
    nodemat = np.zeros((ntaxa,ntaxa))
    pdm = tree.phylogenetic_distance_matrix() # initialises class
    for i,j in itertools.combinations(range(ntaxa),2):
        distmat[i,j] = distmat[j,i] = pdm.distance(tree.taxon_namespace[i], tree.taxon_namespace[j])
        nodemat[i,j] = nodemat[j,i] = pdm.path_edge_count(tree.taxon_namespace[i], tree.taxon_namespace[j])
    if have_paralogs:
        sample = ['_'.join(t.label.split('_')[:3]) for t in tree.taxon_namespace]
        return species, genus, distmat, nodemat, sample
    return species, genus, distmat, nodemat

# %%
def silhouette_str(dist, labels):
    distrib = metrics.silhouette_samples(dist, labels, metric="precomputed")
    return '{:7.3f}'.format(np.percentile(distrib, 5)) + \
    '{:7.3f}'.format(np.percentile(distrib, 25)) + \
    '{:7.3f}  '.format(sum(distrib>0)/float(len(distrib)))

# %% [markdown]
# Each triplet from `silhouette_str()` has $5\%$, $25\%$ and proportion of positive silhouettes. And we have two triplets on the left for _species_ (S), and two on the right for _strain_ (T), one being from weighted (W) and one from unweighted (U) patristic distances. Therefore the header is: SW SU TW TU
#
# By the way having low silhouettte scores is not necessarily bad, since
# 1. clusters of size one will have score of _zero_ **by definition** (should be _one_ given the silhouette function but this would lead to ever-increasing clusterings)
# 2. clusters with within-distance zero are perfect, while for phylogenies we want non-zero diversification
# 3. they can be negative if for a case like `((A:a,A:a,A:a),B:b)` with $a>b$ since $d(A,A)=2a > a+b = d(A,B)$ --- however the taxonomic classification is fine for A and B

# %%
sp, ge, mat, mat2, strain = patristic_distances_from_treefile (outdir + ".fasta.treefile", have_paralogs = True, shuffle = True)
print ("random \t", silhouette_str(mat, sp),  silhouette_str(mat2, sp), " | ", 
      silhouette_str(mat, strain),  silhouette_str(mat2, strain))

for suffix1, title1 in zip(["_upgma.treefile",".fasta.treefile"], ["upgma ", "ML    "]):
    ## operon doenst have _long or _consensus
    sp, ge, mat, mat2, strain = patristic_distances_from_treefile (outdir + suffix1, have_paralogs = True)
    print (title1, "\t", silhouette_str(mat, sp),  silhouette_str(mat2, sp), " | ", 
      silhouette_str(mat, strain),  silhouette_str(mat2, strain))
# Out:
# random 	  -0.536 -0.427  0.005    -0.192 -0.142  0.012    |   -0.963 -0.792  0.005    -0.554 -0.444  0.012
# upgma  	  -0.475  0.527  0.852    -0.493  0.054  0.782    |   -0.978 -0.282  0.482    -0.729 -0.319  0.535
# ML     	  -0.675  0.573  0.815    -0.524 -0.078  0.716    |   -0.932 -0.465  0.450    -0.697 -0.321  0.492

# %%
def sp_count_from_list (labels):
    x = ['_'.join(t.split('_')[:2]) for t in labels]
    return len(set(x))

def strain_count_from_list (labels):
    x = ['_'.join(t.split('_')[:3]) for t in labels]
    return len(set(x))

def bipartitions_from_treefile (filename, shuffle = False):
    tree = dendropy.Tree.get(path=filename, schema="newick", preserve_underscores=True)
    if shuffle:
        tree = dendropy.simulate.treesim.pure_kingman_tree(taxon_namespace=tree.taxon_namespace, pop_size = 1000)
    tree.encode_bipartitions()
    # bits[i] have the list of labels associated to bipartition (edge) i
    bits = [[x.label for x in tree.taxon_namespace.bitmask_taxa_list(i.leafset_bitmask)] for i in tree.bipartition_encoding]
    sp_count = [sp_count_from_list(i) for i in bits if len(i) > 1]
    strain_count = [strain_count_from_list(i) for i in bits if len(i) > 1]
    return sp_count, strain_count

def bipart_str(counts):
    distrib = np.array(counts)
    return '{:7.3f}'.format(np.mean(distrib)) + \
    '{:7.3f}'.format(np.percentile(distrib, 90)) + \
    '{:7.3f}\t'.format(sum(distrib == 1)/float(len(distrib))) 

sp0, ge0 = bipartitions_from_treefile (outdir + ".fasta.treefile", shuffle = True)
print ('{:7s}'.format("random"), "\t", bipart_str(sp0), bipart_str(ge0))

for suffix1, title1 in zip(["_upgma.treefile",".fasta.treefile"], ["upgma ", "ML    "]):
    sp, ge = bipartitions_from_treefile (outdir + suffix1)    
    print ('{:7s}'.format(title1), "\t", bipart_str(sp), bipart_str(ge))
